# %%
from lawson_quant_library.parameter.ir_curve import IRCurve
from lawson_quant_library.util import evaluation_date, Tenor

rate = 0.05

rate_curve = IRCurve(rate=rate)

ref_date = evaluation_date("2026-02-07")

quotes = {"1w": 0.01, "1m": 0.02, "2y": 0.10}

rate_curve.set_deposit_quotes(quotes=quotes, reference_date=ref_date)

print(rate_curve)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from lawson_quant_library.parameter.ir_curve import IRCurve
#       2 from lawson_quant_library.util import evaluation_date, Tenor
#       4 rate = 0.05
#
# File ~/lawson-quant-library/src/lawson_quant_library/parameter/__init__.py:2
#       1 from .parameter import Parameter
# ----> 2 from .curves import IRCurve, DivCurve
#       3 from .vol import EQVol
#       4 from .fx_curve import FXCurve
#
# File ~/lawson-quant-library/src/lawson_quant_library/parameter/curves.py:16
#      12 from typing import Any, Dict, Iterable, List, Optional, Tuple
#      14 import QuantLib as ql
# ---> 16 from lawson_quant_library.util import Calendar, evaluation_date, get_calendar, get_day_count, parse_tenor, to_ql_date
#      18 from .parameter import Parameter
#      22 class CurvePoint:
#
# ImportError: cannot import name 'parse_tenor' from 'lawson_quant_library.util' (/Users/lawsonprendergast/lawson-quant-library/src/lawson_quant_library/util.py)
