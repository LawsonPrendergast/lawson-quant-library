# %%
from lawson_quant_library.parameter.ir_curve import IRCurve
from lawson_quant_library.util import to_ql_date, Calendar, parse_tenor

rate = 0.05
cal = Calendar("US:NYSE", day_count="ACT365F")
cal._ql_calendar()
rate_curve = IRCurve(rate, cal)

ref_date = to_ql_date("2026-02-07")

quotes = {"1W": 0.01, "1M": 0.02, "2Y": 0.10}

tenors = [parse_tenor(t) for t in quotes.keys()]


rate_curve.set_deposit_quotes(quotes=quotes, reference_date=ref_date)

print(rate_curve.table(tenors=tenors, reference_date=ref_date))
# Out:
# [<lawson_quant_library.parameter.ir_curve.CurvePoint object at 0x1063dd2d0>, <lawson_quant_library.parameter.ir_curve.CurvePoint object at 0x1182cd150>, <lawson_quant_library.parameter.ir_curve.CurvePoint object at 0x1063b0590>]

# %%
from lawson_quant_library.data.yahoo_options import YahooOptionsAdapter
import pandas as pd
nvda_opts = YahooOptionsAdapter("NVDA")
'''chain = nvda_opts.option_chain('2026-03-20')
clean_calls = nvda_opts.normalized_chain('2026-03-20', 'call')
spot = nvda_opts.spot()
moneyness = nvda_opts.with_moneyness(clean_calls, spot)

print(moneyness.columns)'''

nvda_calls = nvda_opts.snapshot('2026-03-20', '2026-02-15', True).calls
nvda_opts.with_delta(nvda_calls, 0.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       4 '''chain = nvda_opts.option_chain('2026-03-20')
#       5 clean_calls = nvda_opts.normalized_chain('2026-03-20', 'call')
#       6 spot = nvda_opts.spot()
#       7 moneyness = nvda_opts.with_moneyness(clean_calls, spot)
#       8
#       9 print(moneyness.columns)'''
#      11 nvda_calls = nvda_opts.snapshot('2026-03-20', '2026-02-15', True).calls
# ---> 12 nvda_opts.with_delta(nvda_calls, 0.05)
#
# File ~/lawson-quant-library/src/lawson_quant_library/data/yahoo_options.py:126, in YahooOptionsAdapter.with_delta(self, df, rate, div)
#     124 opt_type = row['type']
#     125 opt = EQOption(expiry, strike, opt_type, style='European', spot=spot, ir_curve=rate_curve, div_curve=div_curve, model='bs_analytic')
# --> 126 iv = opt.implied_vol(mid_price, reference_date=as_of)
#     127 ivs.append(iv)
#     129 model=BlackScholesAnalyticModel(opt, vol=iv)
#
# File ~/lawson-quant-library/src/lawson_quant_library/instrument/option/eq_option.py:97, in EQOption.implied_vol(self, target_price, reference_date, initial_vol, tol, max_iter)
#      94 tmp_vol = EQVol(currency=getattr(self.vol, "currency", "USD"))
#      95 tmp_vol.set_flat_vol(float(sigma), reference_date=reference_date)
# ---> 97 tmp_model = BlackScholesAnalyticModel(self,
#      98     spot=float(self.spot),
#      99     ir_curve=self.ir_curve,
#     100     div_curve=self.div_curve,
#     101     vol=tmp_vol,
#     102 )
#     104 price = float(tmp_model.price(self))
#     105 diff = price - float(target_price)
#
# File ~/lawson-quant-library/src/lawson_quant_library/model/bs_analytic_eq.py:33, in BlackScholesAnalyticModel.__init__(self, option, **kwargs)
#      31 rf_handle = self.ir_curve.handle
#      32 div_handle = self.div_curve.handle
# ---> 33 vol_handle = self.vol.handle
#      38 self._process = BlackScholesMertonProcess(
#      39     self._spot_handle,
#      40     self.div_handle,
#      41     self.rf_handle,
#      42     self.vol_handle,
#      43 )
#      45 self._engine = AnalyticEuropeanEngine(self._process)
#
# AttributeError: 'NoneType' object has no attribute 'handle'

# %%
import QuantLib as ql

d1 = ql.Date(15, 1, 2026)
d2 = ql.Date(15, 7, 2026)
dc = ql.Actual365Fixed()

print("yearFraction method exists:", hasattr(dc, "yearFraction"))
print("Year fraction:", dc.yearFraction(d1, d2))
# Out:
# yearFraction method exists: True
# Year fraction: 0.4958904109589041
